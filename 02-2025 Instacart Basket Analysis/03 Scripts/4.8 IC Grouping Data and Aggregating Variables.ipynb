# %% [markdown]
# # 4.8 IC Grouping Data and Aggregating Variables

# %% [markdown]
# ## Content
#
# 1. **Importing Libraries**
# 2. **Importing Data Frame**
# 3. **Grouping Data with pandas**
# 4. **Aggregating Data with agg()**
# 5. **Aggregating Data with transform()**
# 6. **Deriving Columns with loc() - creating Flag**
# 7. **Task**
#    7.1 Aggregated Mean of "order_number" Column grouped by "department_id" on entire Df
#    7.2 Create loyalty Flag for existing Customers using transform() and loc() Functions
#    7.3 Analysing spending Habits by loyalty Category
#    7.4 Creating spendig Flag for Users
#    7.5 Frequent vs no-frequent User Flag
# 8. **Saving the Data Frame**

# %% [markdown]
# ## 1. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Importing Data Frame

# %%
# Creating the shortcut
path = r'/home/justem/CF - Data Analyst/Achievement 4/02-2025 Instacart Basket Analysis'

# %%
# Importing data set orders, last version
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ordsprods_merge.pkl'))

# %%
# Checking imported df
df_ords_prods_merge.head()

# %%
# Checking shape
df_ords_prods_merge.shape

# %%
# Creating subset df
df = df_ords_prods_merge[:1000000]

# %%
# Checking subset df
df.head()

# %%
# Checking shape df
df.shape

# %% [markdown]
# ## 3. Grouping Data with pandas

# %%
# Trying out groupby() function
df.groupby('product_name')

# %% [markdown]
# ## 4. Aggregating Data with agg()

# %%
# Splitting data into groups based on "department_id" and applying aggregation to each group
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %% [markdown]
# "order_number" refers to number of orders placed by a given user -
#  average number of orders per user for each department

# %%
# Aggregating with mean()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
# Multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# ## 5. Aggregating Data with transform()

# %%
# Aggregating max orders per cutomer
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform("max")

# %%
#Checking result
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order
# 0   both         10
# 1   both         10
# 2   both         10
# 3   both         10
# 4   both         10

# %%
# Checking first 100 rows
df_ords_prods_merge.head(100)

# %%
# Change limited views
pd.options.display.max_rows = None

# %%
# Checking change and first 100 rows
df_ords_prods_merge.head(100)

# %% [markdown]
# ## 6. Deriving Columns with loc() - creating Flag

# %%
# Assigning "loyalty" label "Loyal customer" to orders > 40
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Assigning "loyalty" label "Regular customer" to orders <= 40 & > 10
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Assigning "loyalty" label "New customer" to orders <= 10
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Printing frequency
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Checking column
df_ords_prods_merge['loyalty_flag']
# Out:
# 0               New customer
# 1               New customer
# 2               New customer
# 3               New customer
# 4               New customer
#                   ...
# 32404854    Regular customer
# 32404855    Regular customer
# 32404856    Regular customer
# 32404857    Regular customer
# 32404858    Regular customer
# Name: loyalty_flag, Length: 32404859, dtype: object

# %%
# Multiple columns with head() function
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %% [markdown]
# ## 7. Task

# %% [markdown]
# ### 7.1 Aggregated Mean of "order_number" Column grouped by "department_id" on entire Df

# %%
# Splitting data into groups based on "department_id" and applying aggregation to each group
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# Analyse the result. How do the results for the entire dateframe differ from those of he subset?
# Some numbers are higher and some are smaller compared to the subset results.

# %% [markdown]
# ### 7.2 Create loyalty Flag for existing Customers using transform() and loc() Functions

# %% [markdown]
# Done that under 6.0

# %% [markdown]
# ### 7.3 Analysing spending Habits by loyalty Category

# %% [markdown]
# Comparing spending habits of the three loyalty categories (loyalty_flag) using product prices

# %%
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'median', 'min', 'max']})
# Out:
#                      prices
#                        mean median  min      max
# loyalty_flag
# Loyal customer    10.386336    7.4  1.0  99999.0
# New customer      13.294670    7.4  1.0  99999.0
# Regular customer  12.495717    7.4  1.0  99999.0

# %% [markdown]
# New customers seem have the highest prices of products purchased, followed by customers and with a bigger gap, loyal customers

# %% [markdown]
# ### 7.4 Creating spendig Flag for Users

# %% [markdown]
# Average price across all their orders - mean

# %%
# Aggregating average price per cutomer across their orders
df_ords_prods_merge['mean_spending'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform("mean")

# %%
#Checking result
df_ords_prods_merge.head(30)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      0.0         196                  1          0
# 1                      0.0       14084                  2          0
# 2                      0.0       12427                  3          0
# 3                      0.0       26088                  4          0
# 4                      0.0       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
# 15                    21.0       30450                  5          0
# 16                    29.0         196                  1          1
# 17                    29.0       12427                  2          1
# 18                    29.0       10258                  3          1
# 19                    29.0       25133                  4          1
# 20                    29.0       26405                  5          1
# 21                    28.0         196                  1          1
# 22                    28.0       12427                  2          1
# 23                    28.0       10258                  3          1
# 24                    28.0       25133                  4          1
# 25                    28.0       10326                  5          0
# 26                    28.0       17122                  6          0
# 27                    28.0       41787                  7          0
# 28                    28.0       13176                  8          1
# 29                    19.0         196                  1          1
#
#                                product_name  aisle_id  department_id  prices  \
# 0                                      Soda        77              7     9.0
# 1   Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                       Original Beef Jerky        23             19     4.4
# 3                Aged White Cheddar Popcorn        23             19     4.7
# 4          XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                      Soda        77              7     9.0
# 6                                Pistachios       117             19     3.0
# 7                       Original Beef Jerky        23             19     4.4
# 8                    Bag of Organic Bananas        24              4    10.3
# 9                Aged White Cheddar Popcorn        23             19     4.7
# 10                    Cinnamon Toast Crunch       121             14     4.0
# 11                                     Soda        77              7     9.0
# 12                      Original Beef Jerky        23             19     4.4
# 13                               Pistachios       117             19     3.0
# 14                    Organic String Cheese        21             16     8.6
# 15                     Creamy Almond Butter        88             13     3.2
# 16                                     Soda        77              7     9.0
# 17                      Original Beef Jerky        23             19     4.4
# 18                               Pistachios       117             19     3.0
# 19                    Organic String Cheese        21             16     8.6
# 20         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 21                                     Soda        77              7     9.0
# 22                      Original Beef Jerky        23             19     4.4
# 23                               Pistachios       117             19     3.0
# 24                    Organic String Cheese        21             16     8.6
# 25                      Organic Fuji Apples        24              4     2.7
# 26                        Honeycrisp Apples        24              4    14.0
# 27                           Bartlett Pears        24              4     5.0
# 28                   Bag of Organic Bananas        24              4    10.3
# 29                                     Soda        77              7     9.0
#
#    _merge  max_order  loyalty_flag  mean_spending
# 0    both         10  New customer       6.367797
# 1    both         10  New customer       6.367797
# 2    both         10  New customer       6.367797
# 3    both         10  New customer       6.367797
# 4    both         10  New customer       6.367797
# 5    both         10  New customer       6.367797
# 6    both         10  New customer       6.367797
# 7    both         10  New customer       6.367797
# 8    both         10  New customer       6.367797
# 9    both         10  New customer       6.367797
# 10   both         10  New customer       6.367797
# 11   both         10  New customer       6.367797
# 12   both         10  New customer       6.367797
# 13   both         10  New customer       6.367797
# 14   both         10  New customer       6.367797
# 15   both         10  New customer       6.367797
# 16   both         10  New customer       6.367797
# 17   both         10  New customer       6.367797
# 18   both         10  New customer       6.367797
# 19   both         10  New customer       6.367797
# 20   both         10  New customer       6.367797
# 21   both         10  New customer       6.367797
# 22   both         10  New customer       6.367797
# 23   both         10  New customer       6.367797
# 24   both         10  New customer       6.367797
# 25   both         10  New customer       6.367797
# 26   both         10  New customer       6.367797
# 27   both         10  New customer       6.367797
# 28   both         10  New customer       6.367797
# 29   both         10  New customer       6.367797

# %%
# Assigning "spending_flag" label "Low spender" to orders < 10
df_ords_prods_merge.loc[df_ords_prods_merge['mean_spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Assigning "spending_flag" label "High spender" to orders >= 10
df_ords_prods_merge.loc[df_ords_prods_merge['mean_spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Checking df
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order  loyalty_flag  mean_spending spending_flag
# 0   both         10  New customer       6.367797   Low spender
# 1   both         10  New customer       6.367797   Low spender
# 2   both         10  New customer       6.367797   Low spender
# 3   both         10  New customer       6.367797   Low spender
# 4   both         10  New customer       6.367797   Low spender

# %%
# Checking frequency
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ### 7.5 Frequent vs no-frequent User Flag

# %% [markdown]
# Order frequency flag - regularity user's ordering behaviour according to median in "days_since_prior_order" column
# Flag criteria
# - Median > 20 → "Non-frequent customer"
# - Median > 10 or <= 20 → "Regular customer"
# - Median <= 10 → "Frequent customer"

# %%
# Aggregating median days since prior order cutomer across their orders
df_ords_prods_merge['median_order_prior_days'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform("median")

# %%
# Check df
df_ords_prods_merge.head(50)

# %%
# Check frequency df
df_ords_prods_merge['median_order_prior_days'].value_counts(dropna = False)

# %%
# Assigning "order_frequency_flag" label "Non-frequent customer" to days prior order's mean > 20
df_ords_prods_merge.loc[df_ords_prods_merge['median_order_prior_days'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Assigning "order_frequency_flag" label "Regular customer" to days prior order's mean > 10 or <= 20
df_ords_prods_merge.loc[(df_ords_prods_merge['median_order_prior_days'] > 10) & (df_ords_prods_merge['median_order_prior_days'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Assigning "order_frequency_flag" label "Frequent customer" to days prior order's mean <= 10
df_ords_prods_merge.loc[df_ords_prods_merge['median_order_prior_days'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Check df
df_ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
# 30   3367565        1             6                   2                  7
# 31   3367565        1             6                   2                  7
# 32   3367565        1             6                   2                  7
# 33    550135        1             7                   1                  9
# 34    550135        1             7                   1                  9
# 35    550135        1             7                   1                  9
# 36    550135        1             7                   1                  9
# 37    550135        1             7                   1                  9
# 38   3108588        1             8                   1                 14
# 39   3108588        1             8                   1                 14
# 40   3108588        1             8                   1                 14
# 41   3108588        1             8                   1                 14
# 42   3108588        1             8                   1                 14
# 43   3108588        1             8                   1                 14
# 44   2295261        1             9                   1                 16
# 45   2295261        1             9                   1                 16
# 46   2295261        1             9                   1                 16
# 47   2295261        1             9                   1                 16
# 48   2295261        1             9                   1                 16
# 49   2295261        1             9                   1                 16
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      0.0         196                  1          0
# 1                      0.0       14084                  2          0
# 2                      0.0       12427                  3          0
# 3                      0.0       26088                  4          0
# 4                      0.0       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
# 15                    21.0       30450                  5          0
# 16                    29.0         196                  1          1
# 17                    29.0       12427                  2          1
# 18                    29.0       10258                  3          1
# 19                    29.0       25133                  4          1
# 20                    29.0       26405                  5          1
# 21                    28.0         196                  1          1
# 22                    28.0       12427                  2          1
# 23                    28.0       10258                  3          1
# 24                    28.0       25133                  4          1
# 25                    28.0       10326                  5          0
# 26                    28.0       17122                  6          0
# 27                    28.0       41787                  7          0
# 28                    28.0       13176                  8          1
# 29                    19.0         196                  1          1
# 30                    19.0       12427                  2          1
# 31                    19.0       10258                  3          1
# 32                    19.0       25133                  4          1
# 33                    20.0         196                  1          1
# 34                    20.0       10258                  2          1
# 35                    20.0       12427                  3          1
# 36                    20.0       25133                  4          1
# 37                    20.0       13032                  5          1
# 38                    14.0       12427                  1          1
# 39                    14.0         196                  2          1
# 40                    14.0       10258                  3          1
# 41                    14.0       25133                  4          1
# 42                    14.0       46149                  5          0
# 43                    14.0       49235                  6          0
# 44                     0.0       49235                  1          1
# 45                     0.0       46149                  2          1
# 46                     0.0       25133                  3          1
# 47                     0.0         196                  4          1
# 48                     0.0       10258                  5          1
# 49                     0.0       12427                  6          1
#
#                                product_name  aisle_id  department_id  prices  \
# 0                                      Soda        77              7     9.0
# 1   Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                       Original Beef Jerky        23             19     4.4
# 3                Aged White Cheddar Popcorn        23             19     4.7
# 4          XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                      Soda        77              7     9.0
# 6                                Pistachios       117             19     3.0
# 7                       Original Beef Jerky        23             19     4.4
# 8                    Bag of Organic Bananas        24              4    10.3
# 9                Aged White Cheddar Popcorn        23             19     4.7
# 10                    Cinnamon Toast Crunch       121             14     4.0
# 11                                     Soda        77              7     9.0
# 12                      Original Beef Jerky        23             19     4.4
# 13                               Pistachios       117             19     3.0
# 14                    Organic String Cheese        21             16     8.6
# 15                     Creamy Almond Butter        88             13     3.2
# 16                                     Soda        77              7     9.0
# 17                      Original Beef Jerky        23             19     4.4
# 18                               Pistachios       117             19     3.0
# 19                    Organic String Cheese        21             16     8.6
# 20         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 21                                     Soda        77              7     9.0
# 22                      Original Beef Jerky        23             19     4.4
# 23                               Pistachios       117             19     3.0
# 24                    Organic String Cheese        21             16     8.6
# 25                      Organic Fuji Apples        24              4     2.7
# 26                        Honeycrisp Apples        24              4    14.0
# 27                           Bartlett Pears        24              4     5.0
# 28                   Bag of Organic Bananas        24              4    10.3
# 29                                     Soda        77              7     9.0
# 30                      Original Beef Jerky        23             19     4.4
# 31                               Pistachios       117             19     3.0
# 32                    Organic String Cheese        21             16     8.6
# 33                                     Soda        77              7     9.0
# 34                               Pistachios       117             19     3.0
# 35                      Original Beef Jerky        23             19     4.4
# 36                    Organic String Cheese        21             16     8.6
# 37                    Cinnamon Toast Crunch       121             14     4.0
# 38                      Original Beef Jerky        23             19     4.4
# 39                                     Soda        77              7     9.0
# 40                               Pistachios       117             19     3.0
# 41                    Organic String Cheese        21             16     8.6
# 42                        Zero Calorie Cola        77              7    13.4
# 43                      Organic Half & Half        53             16     1.8
# 44                      Organic Half & Half        53             16     1.8
# 45                        Zero Calorie Cola        77              7    13.4
# 46                    Organic String Cheese        21             16     8.6
# 47                                     Soda        77              7     9.0
# 48                               Pistachios       117             19     3.0
# 49                      Original Beef Jerky        23             19     4.4
#
#    _merge  max_order  loyalty_flag  mean_spending spending_flag  \
# 0    both         10  New customer       6.367797   Low spender
# 1    both         10  New customer       6.367797   Low spender
# 2    both         10  New customer       6.367797   Low spender
# 3    both         10  New customer       6.367797   Low spender
# 4    both         10  New customer       6.367797   Low spender
# 5    both         10  New customer       6.367797   Low spender
# 6    both         10  New customer       6.367797   Low spender
# 7    both         10  New customer       6.367797   Low spender
# 8    both         10  New customer       6.367797   Low spender
# 9    both         10  New customer       6.367797   Low spender
# 10   both         10  New customer       6.367797   Low spender
# 11   both         10  New customer       6.367797   Low spender
# 12   both         10  New customer       6.367797   Low spender
# 13   both         10  New customer       6.367797   Low spender
# 14   both         10  New customer       6.367797   Low spender
# 15   both         10  New customer       6.367797   Low spender
# 16   both         10  New customer       6.367797   Low spender
# 17   both         10  New customer       6.367797   Low spender
# 18   both         10  New customer       6.367797   Low spender
# 19   both         10  New customer       6.367797   Low spender
# 20   both         10  New customer       6.367797   Low spender
# 21   both         10  New customer       6.367797   Low spender
# 22   both         10  New customer       6.367797   Low spender
# 23   both         10  New customer       6.367797   Low spender
# 24   both         10  New customer       6.367797   Low spender
# 25   both         10  New customer       6.367797   Low spender
# 26   both         10  New customer       6.367797   Low spender
# 27   both         10  New customer       6.367797   Low spender
# 28   both         10  New customer       6.367797   Low spender
# 29   both         10  New customer       6.367797   Low spender
# 30   both         10  New customer       6.367797   Low spender
# 31   both         10  New customer       6.367797   Low spender
# 32   both         10  New customer       6.367797   Low spender
# 33   both         10  New customer       6.367797   Low spender
# 34   both         10  New customer       6.367797   Low spender
# 35   both         10  New customer       6.367797   Low spender
# 36   both         10  New customer       6.367797   Low spender
# 37   both         10  New customer       6.367797   Low spender
# 38   both         10  New customer       6.367797   Low spender
# 39   both         10  New customer       6.367797   Low spender
# 40   both         10  New customer       6.367797   Low spender
# 41   both         10  New customer       6.367797   Low spender
# 42   both         10  New customer       6.367797   Low spender
# 43   both         10  New customer       6.367797   Low spender
# 44   both         10  New customer       6.367797   Low spender
# 45   both         10  New customer       6.367797   Low spender
# 46   both         10  New customer       6.367797   Low spender
# 47   both         10  New customer       6.367797   Low spender
# 48   both         10  New customer       6.367797   Low spender
# 49   both         10  New customer       6.367797   Low spender
#
#     median_order_prior_days order_frequency_flag
# 0                      20.0     Regular customer
# 1                      20.0     Regular customer
# 2                      20.0     Regular customer
# 3                      20.0     Regular customer
# 4                      20.0     Regular customer
# 5                      20.0     Regular customer
# 6                      20.0     Regular customer
# 7                      20.0     Regular customer
# 8                      20.0     Regular customer
# 9                      20.0     Regular customer
# 10                     20.0     Regular customer
# 11                     20.0     Regular customer
# 12                     20.0     Regular customer
# 13                     20.0     Regular customer
# 14                     20.0     Regular customer
# 15                     20.0     Regular customer
# 16                     20.0     Regular customer
# 17                     20.0     Regular customer
# 18                     20.0     Regular customer
# 19                     20.0     Regular customer
# 20                     20.0     Regular customer
# 21                     20.0     Regular customer
# 22                     20.0     Regular customer
# 23                     20.0     Regular customer
# 24                     20.0     Regular customer
# 25                     20.0     Regular customer
# 26                     20.0     Regular customer
# 27                     20.0     Regular customer
# 28                     20.0     Regular customer
# 29                     20.0     Regular customer
# 30                     20.0     Regular customer
# 31                     20.0     Regular customer
# 32                     20.0     Regular customer
# 33                     20.0     Regular customer
# 34                     20.0     Regular customer
# 35                     20.0     Regular customer
# 36                     20.0     Regular customer
# 37                     20.0     Regular customer
# 38                     20.0     Regular customer
# 39                     20.0     Regular customer
# 40                     20.0     Regular customer
# 41                     20.0     Regular customer
# 42                     20.0     Regular customer
# 43                     20.0     Regular customer
# 44                     20.0     Regular customer
# 45                     20.0     Regular customer
# 46                     20.0     Regular customer
# 47                     20.0     Regular customer
# 48                     20.0     Regular customer
# 49                     20.0     Regular customer

# %%
# Check frequency df
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        22796659
# Regular customer          6921472
# Non-frequent customer     2686728
# Name: count, dtype: int64

# %% [markdown]
# ##  8. Saving the Data Frame

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_prods_merge_agg_variables.pkl'))
